# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

data = np.random.rand(100)

labels = ["Class1" if x <= 0.5 else "Class2" for x in data[:50]]


def euclidean_distance(x1, x2):
    return abs(x1 - x2)


def knn_classifier(train_data, train_labels, test_point, k):
    distances = [(euclidean_distance(test_point, train_data[i]), train_labels[i]) for i in range(len(train_data))]

    distances.sort(key=lambda x: x[0])
    k_nearest_neighbors = distances[:k]

    k_nearest_labels = [label for _, label in k_nearest_neighbors]

    return Counter(k_nearest_labels).most_common(1)[0][0]


train_data = data[:50]
train_labels = labels

test_data = data[50:]

k_values = [1, 2, 3, 4, 5, 20, 30]

print("--- k-Nearest Neighbors Classification ---")
print("Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)")
print("Testing dataset: Remaining 50 points to be classified\n")

results = {}

for k in k_values:
    print(f"Results for k = {k}:")
    classified_labels = [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data]
    results[k] = classified_labels

    for i, label in enumerate(classified_labels, start=51):
        print(f"Point x{i} (value: {test_data[i - 51]:.4f}) is classified as {label}")
    print("\n")

print("Classification complete.\n")

for k in k_values:
    classified_labels = results[k]
    class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"]
    class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"]

    plt.figure(figsize=(10, 6))
    plt.scatter(train_data, [0] * len(train_data), c=["blue" if label == "Class1" else "red" for label in train_labels],
                label="Training Data", marker="o")
    plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker="x")
    plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker="x")

    plt.title(f"k-NN Classification Results for k = {k}")
    plt.xlabel("Data Points")
    plt.ylabel("Classification Level")
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# --- k-Nearest Neighbors Classification ---
# Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)
# Testing dataset: Remaining 50 points to be classified
#
# Results for k = 1:
# Point x51 (value: 0.5313) is classified as Class2
# Point x52 (value: 0.2317) is classified as Class1
# Point x53 (value: 0.9089) is classified as Class2
# Point x54 (value: 0.4049) is classified as Class1
# Point x55 (value: 0.0152) is classified as Class1
# Point x56 (value: 0.1485) is classified as Class1
# Point x57 (value: 0.8162) is classified as Class2
# Point x58 (value: 0.8704) is classified as Class2
# Point x59 (value: 0.3845) is classified as Class1
# Point x60 (value: 0.0335) is classified as Class1
# Point x61 (value: 0.4236) is classified as Class1
# Point x62 (value: 0.2407) is classified as Class1
# Point x63 (value: 0.1651) is classified as Class1
# Point x64 (value: 0.5800) is classified as Class2
# Point x65 (value: 0.1477) is classified as Class1
# Point x66 (value: 0.7861) is classified as Class2
# Point x67 (value: 0.6822) is classified as Class2
# Point x68 (value: 0.4233) is classified as Class1
# Point x69 (value: 0.2696) is classified as Class1
# Point x70 (value: 0.6842) is classified as Class2
# Point x71 (value: 0.6396) is classified as Class2
# Point x72 (value: 0.8762) is classified as Class2
# Point x73 (value: 0.7361) is classified as Class2
# Point x74 (value: 0.2500) is classified as Class1
# Point x75 (value: 0.1824) is classified as Class1
# Point x76 (value: 0.3621) is classified as Class1
# Point x77 (value: 0.1066) is classified as Class1
# Point x78 (value: 0.0273) is classified as Class1
# Point x79 (value: 0.1208) is classified as Class1
# Point x80 (value: 0.6644) is classified as Class2
# Point x81 (value: 0.4054) is classified as Class1
# Point x82 (value: 0.3804) is classified as Class1
# Point x83 (value: 0.6493) is classified as Class2
# Point x84 (value: 0.6141) is classified as Class2
# Point x85 (value: 0.6571) is classified as Class2
# Point x86 (value: 0.4471) is classified as Class1
# Point x87 (value: 0.2207) is classified as Class1
# Point x88 (value: 0.1833) is classified as Class1
# Point x89 (value: 0.1764) is classified as Class1
# Point x90 (value: 0.5514) is classified as Class2
# Point x91 (value: 0.4746) is classified as Class1
# Point x92 (value: 0.4137) is classified as Class1
# Point x93 (value: 0.5361) is classified as Class2
# Point x94 (value: 0.7346) is classified as Class2
# Point x95 (value: 0.2117) is classified as Class1
# Point x96 (value: 0.3440) is classified as Class1
# Point x97 (value: 0.3916) is classified as Class1
# Point x98 (value: 0.6080) is classified as Class2
# Point x99 (value: 0.7850) is classified as Class2
# Point x100 (value: 0.7624) is classified as Class2
#
#
# Results for k = 2:
# Point x51 (value: 0.5313) is classified as Class2
# Point x52 (value: 0.2317) is classified as Class1
# Point x53 (value: 0.9089) is classified as Class2
# Point x54 (value: 0.4049) is classified as Class1
# Point x55 (value: 0.0152) is classified as Class1
# Point x56 (value: 0.1485) is classified as Class1
# Point x57 (value: 0.8162) is classified as Class2
# Point x58 (value: 0.8704) is classified as Class2
# Point x59 (value: 0.3845) is classified as Class1
# Point x60 (value: 0.0335) is classified as Class1
# Point x61 (value: 0.4236) is classified as Class1
# Point x62 (value: 0.2407) is classified as Class1
# Point x63 (value: 0.1651) is classified as Class1
# Point x64 (value: 0.5800) is classified as Class2
# Point x65 (value: 0.1477) is classified as Class1
# Point x66 (value: 0.7861) is classified as Class2
# Point x67 (value: 0.6822) is classified as Class2
# Point x68 (value: 0.4233) is classified as Class1
# Point x69 (value: 0.2696) is classified as Class1
# Point x70 (value: 0.6842) is classified as Class2
# Point x71 (value: 0.6396) is classified as Class2
# Point x72 (value: 0.8762) is classified as Class2
# Point x73 (value: 0.7361) is classified as Class2
# Point x74 (value: 0.2500) is classified as Class1
# Point x75 (value: 0.1824) is classified as Class1
# Point x76 (value: 0.3621) is classified as Class1
# Point x77 (value: 0.1066) is classified as Class1
# Point x78 (value: 0.0273) is classified as Class1
# Point x79 (value: 0.1208) is classified as Class1
# Point x80 (value: 0.6644) is classified as Class2
# Point x81 (value: 0.4054) is classified as Class1
# Point x82 (value: 0.3804) is classified as Class1
# Point x83 (value: 0.6493) is classified as Class2
# Point x84 (value: 0.6141) is classified as Class2
# Point x85 (value: 0.6571) is classified as Class2
# Point x86 (value: 0.4471) is classified as Class1
# Point x87 (value: 0.2207) is classified as Class1
# Point x88 (value: 0.1833) is classified as Class1
# Point x89 (value: 0.1764) is classified as Class1
# Point x90 (value: 0.5514) is classified as Class2
# Point x91 (value: 0.4746) is classified as Class1
# Point x92 (value: 0.4137) is classified as Class1
# Point x93 (value: 0.5361) is classified as Class2
# Point x94 (value: 0.7346) is classified as Class2
# Point x95 (value: 0.2117) is classified as Class1
# Point x96 (value: 0.3440) is classified as Class1
# Point x97 (value: 0.3916) is classified as Class1
# Point x98 (value: 0.6080) is classified as Class2
# Point x99 (value: 0.7850) is classified as Class2
# Point x100 (value: 0.7624) is classified as Class2
#
#
# Results for k = 3:
# Point x51 (value: 0.5313) is classified as Class2
# Point x52 (value: 0.2317) is classified as Class1
# Point x53 (value: 0.9089) is classified as Class2
# Point x54 (value: 0.4049) is classified as Class1
# Point x55 (value: 0.0152) is classified as Class1
# Point x56 (value: 0.1485) is classified as Class1
# Point x57 (value: 0.8162) is classified as Class2
# Point x58 (value: 0.8704) is classified as Class2
# Point x59 (value: 0.3845) is classified as Class1
# Point x60 (value: 0.0335) is classified as Class1
# Point x61 (value: 0.4236) is classified as Class1
# Point x62 (value: 0.2407) is classified as Class1
# Point x63 (value: 0.1651) is classified as Class1
# Point x64 (value: 0.5800) is classified as Class2
# Point x65 (value: 0.1477) is classified as Class1
# Point x66 (value: 0.7861) is classified as Class2
# Point x67 (value: 0.6822) is classified as Class2
# Point x68 (value: 0.4233) is classified as Class1
# Point x69 (value: 0.2696) is classified as Class1
# Point x70 (value: 0.6842) is classified as Class2
# Point x71 (value: 0.6396) is classified as Class2
# Point x72 (value: 0.8762) is classified as Class2
# Point x73 (value: 0.7361) is classified as Class2
# Point x74 (value: 0.2500) is classified as Class1
# Point x75 (value: 0.1824) is classified as Class1
# Point x76 (value: 0.3621) is classified as Class1
# Point x77 (value: 0.1066) is classified as Class1
# Point x78 (value: 0.0273) is classified as Class1
# Point x79 (value: 0.1208) is classified as Class1
# Point x80 (value: 0.6644) is classified as Class2
# Point x81 (value: 0.4054) is classified as Class1
# Point x82 (value: 0.3804) is classified as Class1
# Point x83 (value: 0.6493) is classified as Class2
# Point x84 (value: 0.6141) is classified as Class2
# Point x85 (value: 0.6571) is classified as Class2
# Point x86 (value: 0.4471) is classified as Class1
# Point x87 (value: 0.2207) is classified as Class1
# Point x88 (value: 0.1833) is classified as Class1
# Point x89 (value: 0.1764) is classified as Class1
# Point x90 (value: 0.5514) is classified as Class2
# Point x91 (value: 0.4746) is classified as Class1
# Point x92 (value: 0.4137) is classified as Class1
# Point x93 (value: 0.5361) is classified as Class2
# Point x94 (value: 0.7346) is classified as Class2
# Point x95 (value: 0.2117) is classified as Class1
# Point x96 (value: 0.3440) is classified as Class1
# Point x97 (value: 0.3916) is classified as Class1
# Point x98 (value: 0.6080) is classified as Class2
# Point x99 (value: 0.7850) is classified as Class2
# Point x100 (value: 0.7624) is classified as Class2
#
#
# Results for k = 4:
# Point x51 (value: 0.5313) is classified as Class2
# Point x52 (value: 0.2317) is classified as Class1
# Point x53 (value: 0.9089) is classified as Class2
# Point x54 (value: 0.4049) is classified as Class1
# Point x55 (value: 0.0152) is classified as Class1
# Point x56 (value: 0.1485) is classified as Class1
# Point x57 (value: 0.8162) is classified as Class2
# Point x58 (value: 0.8704) is classified as Class2
# Point x59 (value: 0.3845) is classified as Class1
# Point x60 (value: 0.0335) is classified as Class1
# Point x61 (value: 0.4236) is classified as Class1
# Point x62 (value: 0.2407) is classified as Class1
# Point x63 (value: 0.1651) is classified as Class1
# Point x64 (value: 0.5800) is classified as Class2
# Point x65 (value: 0.1477) is classified as Class1
# Point x66 (value: 0.7861) is classified as Class2
# Point x67 (value: 0.6822) is classified as Class2
# Point x68 (value: 0.4233) is classified as Class1
# Point x69 (value: 0.2696) is classified as Class1
# Point x70 (value: 0.6842) is classified as Class2
# Point x71 (value: 0.6396) is classified as Class2
# Point x72 (value: 0.8762) is classified as Class2
# Point x73 (value: 0.7361) is classified as Class2
# Point x74 (value: 0.2500) is classified as Class1
# Point x75 (value: 0.1824) is classified as Class1
# Point x76 (value: 0.3621) is classified as Class1
# Point x77 (value: 0.1066) is classified as Class1
# Point x78 (value: 0.0273) is classified as Class1
# Point x79 (value: 0.1208) is classified as Class1
# Point x80 (value: 0.6644) is classified as Class2
# Point x81 (value: 0.4054) is classified as Class1
# Point x82 (value: 0.3804) is classified as Class1
# Point x83 (value: 0.6493) is classified as Class2
# Point x84 (value: 0.6141) is classified as Class2
# Point x85 (value: 0.6571) is classified as Class2
# Point x86 (value: 0.4471) is classified as Class1
# Point x87 (value: 0.2207) is classified as Class1
# Point x88 (value: 0.1833) is classified as Class1
# Point x89 (value: 0.1764) is classified as Class1
# Point x90 (value: 0.5514) is classified as Class2
# Point x91 (value: 0.4746) is classified as Class1
# Point x92 (value: 0.4137) is classified as Class1
# Point x93 (value: 0.5361) is classified as Class2
# Point x94 (value: 0.7346) is classified as Class2
# Point x95 (value: 0.2117) is classified as Class1
# Point x96 (value: 0.3440) is classified as Class1
# Point x97 (value: 0.3916) is classified as Class1
# Point x98 (value: 0.6080) is classified as Class2
# Point x99 (value: 0.7850) is classified as Class2
# Point x100 (value: 0.7624) is classified as Class2
#
#
# Results for k = 5:
# Point x51 (value: 0.5313) is classified as Class2
# Point x52 (value: 0.2317) is classified as Class1
# Point x53 (value: 0.9089) is classified as Class2
# Point x54 (value: 0.4049) is classified as Class1
# Point x55 (value: 0.0152) is classified as Class1
# Point x56 (value: 0.1485) is classified as Class1
# Point x57 (value: 0.8162) is classified as Class2
# Point x58 (value: 0.8704) is classified as Class2
# Point x59 (value: 0.3845) is classified as Class1
# Point x60 (value: 0.0335) is classified as Class1
# Point x61 (value: 0.4236) is classified as Class1
# Point x62 (value: 0.2407) is classified as Class1
# Point x63 (value: 0.1651) is classified as Class1
# Point x64 (value: 0.5800) is classified as Class2
# Point x65 (value: 0.1477) is classified as Class1
# Point x66 (value: 0.7861) is classified as Class2
# Point x67 (value: 0.6822) is classified as Class2
# Point x68 (value: 0.4233) is classified as Class1
# Point x69 (value: 0.2696) is classified as Class1
# Point x70 (value: 0.6842) is classified as Class2
# Point x71 (value: 0.6396) is classified as Class2
# Point x72 (value: 0.8762) is classified as Class2
# Point x73 (value: 0.7361) is classified as Class2
# Point x74 (value: 0.2500) is classified as Class1
# Point x75 (value: 0.1824) is classified as Class1
# Point x76 (value: 0.3621) is classified as Class1
# Point x77 (value: 0.1066) is classified as Class1
# Point x78 (value: 0.0273) is classified as Class1
# Point x79 (value: 0.1208) is classified as Class1
# Point x80 (value: 0.6644) is classified as Class2
# Point x81 (value: 0.4054) is classified as Class1
# Point x82 (value: 0.3804) is classified as Class1
# Point x83 (value: 0.6493) is classified as Class2
# Point x84 (value: 0.6141) is classified as Class2
# Point x85 (value: 0.6571) is classified as Class2
# Point x86 (value: 0.4471) is classified as Class1
# Point x87 (value: 0.2207) is classified as Class1
# Point x88 (value: 0.1833) is classified as Class1
# Point x89 (value: 0.1764) is classified as Class1
# Point x90 (value: 0.5514) is classified as Class2
# Point x91 (value: 0.4746) is classified as Class1
# Point x92 (value: 0.4137) is classified as Class1
# Point x93 (value: 0.5361) is classified as Class2
# Point x94 (value: 0.7346) is classified as Class2
# Point x95 (value: 0.2117) is classified as Class1
# Point x96 (value: 0.3440) is classified as Class1
# Point x97 (value: 0.3916) is classified as Class1
# Point x98 (value: 0.6080) is classified as Class2
# Point x99 (value: 0.7850) is classified as Class2
# Point x100 (value: 0.7624) is classified as Class2
#
#
# Results for k = 20:
# Point x51 (value: 0.5313) is classified as Class2
# Point x52 (value: 0.2317) is classified as Class1
# Point x53 (value: 0.9089) is classified as Class2
# Point x54 (value: 0.4049) is classified as Class1
# Point x55 (value: 0.0152) is classified as Class1
# Point x56 (value: 0.1485) is classified as Class1
# Point x57 (value: 0.8162) is classified as Class2
# Point x58 (value: 0.8704) is classified as Class2
# Point x59 (value: 0.3845) is classified as Class1
# Point x60 (value: 0.0335) is classified as Class1
# Point x61 (value: 0.4236) is classified as Class1
# Point x62 (value: 0.2407) is classified as Class1
# Point x63 (value: 0.1651) is classified as Class1
# Point x64 (value: 0.5800) is classified as Class2
# Point x65 (value: 0.1477) is classified as Class1
# Point x66 (value: 0.7861) is classified as Class2
# Point x67 (value: 0.6822) is classified as Class2
# Point x68 (value: 0.4233) is classified as Class1
# Point x69 (value: 0.2696) is classified as Class1
# Point x70 (value: 0.6842) is classified as Class2
# Point x71 (value: 0.6396) is classified as Class2
# Point x72 (value: 0.8762) is classified as Class2
# Point x73 (value: 0.7361) is classified as Class2
# Point x74 (value: 0.2500) is classified as Class1
# Point x75 (value: 0.1824) is classified as Class1
# Point x76 (value: 0.3621) is classified as Class1
# Point x77 (value: 0.1066) is classified as Class1
# Point x78 (value: 0.0273) is classified as Class1
# Point x79 (value: 0.1208) is classified as Class1
# Point x80 (value: 0.6644) is classified as Class2
# Point x81 (value: 0.4054) is classified as Class1
# Point x82 (value: 0.3804) is classified as Class1
# Point x83 (value: 0.6493) is classified as Class2
# Point x84 (value: 0.6141) is classified as Class2
# Point x85 (value: 0.6571) is classified as Class2
# Point x86 (value: 0.4471) is classified as Class2
# Point x87 (value: 0.2207) is classified as Class1
# Point x88 (value: 0.1833) is classified as Class1
# Point x89 (value: 0.1764) is classified as Class1
# Point x90 (value: 0.5514) is classified as Class2
# Point x91 (value: 0.4746) is classified as Class2
# Point x92 (value: 0.4137) is classified as Class1
# Point x93 (value: 0.5361) is classified as Class2
# Point x94 (value: 0.7346) is classified as Class2
# Point x95 (value: 0.2117) is classified as Class1
# Point x96 (value: 0.3440) is classified as Class1
# Point x97 (value: 0.3916) is classified as Class1
# Point x98 (value: 0.6080) is classified as Class2
# Point x99 (value: 0.7850) is classified as Class2
# Point x100 (value: 0.7624) is classified as Class2
#
#
# Results for k = 30:
# Point x51 (value: 0.5313) is classified as Class2
# Point x52 (value: 0.2317) is classified as Class1
# Point x53 (value: 0.9089) is classified as Class2
# Point x54 (value: 0.4049) is classified as Class1
# Point x55 (value: 0.0152) is classified as Class1
# Point x56 (value: 0.1485) is classified as Class1
# Point x57 (value: 0.8162) is classified as Class2
# Point x58 (value: 0.8704) is classified as Class2
# Point x59 (value: 0.3845) is classified as Class1
# Point x60 (value: 0.0335) is classified as Class1
# Point x61 (value: 0.4236) is classified as Class2
# Point x62 (value: 0.2407) is classified as Class1
# Point x63 (value: 0.1651) is classified as Class1
# Point x64 (value: 0.5800) is classified as Class2
# Point x65 (value: 0.1477) is classified as Class1
# Point x66 (value: 0.7861) is classified as Class2
# Point x67 (value: 0.6822) is classified as Class2
# Point x68 (value: 0.4233) is classified as Class2
# Point x69 (value: 0.2696) is classified as Class1
# Point x70 (value: 0.6842) is classified as Class2
# Point x71 (value: 0.6396) is classified as Class2
# Point x72 (value: 0.8762) is classified as Class2
# Point x73 (value: 0.7361) is classified as Class2
# Point x74 (value: 0.2500) is classified as Class1
# Point x75 (value: 0.1824) is classified as Class1
# Point x76 (value: 0.3621) is classified as Class1
# Point x77 (value: 0.1066) is classified as Class1
# Point x78 (value: 0.0273) is classified as Class1
# Point x79 (value: 0.1208) is classified as Class1
# Point x80 (value: 0.6644) is classified as Class2
# Point x81 (value: 0.4054) is classified as Class1
# Point x82 (value: 0.3804) is classified as Class1
# Point x83 (value: 0.6493) is classified as Class2
# Point x84 (value: 0.6141) is classified as Class2
# Point x85 (value: 0.6571) is classified as Class2
# Point x86 (value: 0.4471) is classified as Class2
# Point x87 (value: 0.2207) is classified as Class1
# Point x88 (value: 0.1833) is classified as Class1
# Point x89 (value: 0.1764) is classified as Class1
# Point x90 (value: 0.5514) is classified as Class2
# Point x91 (value: 0.4746) is classified as Class2
# Point x92 (value: 0.4137) is classified as Class1
# Point x93 (value: 0.5361) is classified as Class2
# Point x94 (value: 0.7346) is classified as Class2
# Point x95 (value: 0.2117) is classified as Class1
# Point x96 (value: 0.3440) is classified as Class1
# Point x97 (value: 0.3916) is classified as Class1
# Point x98 (value: 0.6080) is classified as Class2
# Point x99 (value: 0.7850) is classified as Class2
# Point x100 (value: 0.7624) is classified as Class2
#
#
# Classification complete.
